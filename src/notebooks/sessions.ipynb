# %%
import pyarrow.dataset as ds
import pyarrow.parquet as pq
import pandas as pd

base_path = "/home/hygo2025/Documents/data/processed_data/enriched_events"

# %%
dataset = ds.dataset(base_path, format="parquet", partitioning="hive")
cols_to_drop = ["unified_user_id", "listing_id", "user_id", "anonymous_id"]

all_cols = dataset.schema.names
cols_to_keep = [c for c in all_cols if c not in cols_to_drop]

table = dataset.to_table(columns=cols_to_keep)

rename_map = {
    "listing_id_numeric": "listing_id",
    "user_numeric_id": "user_id"
}
for old_name, new_name in rename_map.items():
    if old_name in table.column_names:
        table = table.rename_columns([
            new_name if c == old_name else c
            for c in table.column_names
        ])

first_cols = ["user_id", "listing_id", "name_raw", "event_type"]
rest_cols = [c for c in table.column_names if c not in first_cols]
new_order = first_cols + rest_cols
table = table.select(new_order)

df = table.to_pandas()

print(df.shape)
print(df.columns.tolist())
df.head()
# Out:
# (19126387, 22)
# ['user_id', 'listing_id', 'name_raw', 'event_type', 'browser_family', 'os_family', 'collector_timestamp', 'business_type', 'event_ts', 'state', 'city', 'neighborhood', 'price', 'usable_areas', 'total_areas', 'bathrooms', 'bedrooms', 'suites', 'parking_spaces', 'amenities', 'geopoint', 'dt']
#    user_id  listing_id         name_raw      event_type browser_family  \
# 0      103     1450584  ListingRendered           VISIT  Chrome Mobile
# 1      103     1450584  ListingRendered           VISIT  Chrome Mobile
# 2      304     1987731   RankingClicked  LEAD_INTENTION  Chrome Mobile
# 3      304     1529573   RankingClicked  LEAD_INTENTION  Chrome Mobile
# 4      304     1529573  ListingRendered           VISIT  Chrome Mobile
#
#   os_family collector_timestamp business_type                event_ts  state  \
# 0   Android       1706800846835          SALE 2024-02-01 15:20:46.835  bahia
# 1   Android       1706797670251          SALE 2024-02-01 14:27:50.251  bahia
# 2   Android       1706794623317          SALE 2024-02-01 13:37:03.317  bahia
# 3   Android       1706794579394          SALE 2024-02-01 13:36:19.394  bahia
# 4   Android       1706794583642          SALE 2024-02-01 13:36:23.642  bahia
#
#    ...     price usable_areas  total_areas  bathrooms  bedrooms  suites  \
# 0  ...  387000.0         57.0         57.0        2.0       2.0     0.0
# 1  ...  387000.0         57.0         57.0        2.0       2.0     0.0
# 2  ...  290000.0       2000.0       6200.0        NaN       NaN     NaN
# 3  ...   98000.0        868.0        868.0        NaN       0.0     NaN
# 4  ...   98000.0        868.0        868.0        NaN       0.0     NaN
#
#    parking_spaces                                   amenities  \
# 0             1.0  ['KITCHEN', 'ELEVATOR', 'GATED_COMMUNITY']
# 1             1.0  ['KITCHEN', 'ELEVATOR', 'GATED_COMMUNITY']
# 2             NaN                                          []
# 3             NaN                                ['SEA_VIEW']
# 4             NaN                                ['SEA_VIEW']
#
#                   geopoint          dt
# 0  -38.4896543,-12.9881887  2024-02-01
# 1  -38.4896543,-12.9881887  2024-02-01
# 2  -38.0069504,-12.4844471  2024-02-01
# 3  -38.0069504,-12.4844471  2024-02-01
# 4  -38.0069504,-12.4844471  2024-02-01
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19126387 entries, 0 to 19126386
# Data columns (total 22 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   user_id              int32
#  1   listing_id           int32
#  2   name_raw             object
#  3   event_type           object
#  4   browser_family       object
#  5   os_family            object
#  6   collector_timestamp  object
#  7   business_type        object
#  8   event_ts             datetime64[ns]
#  9   state                object
#  10  city                 object
#  11  neighborhood         object
#  12  price                float64
#  13  usable_areas         float64
#  14  total_areas          float64
#  15  bathrooms            float64
#  16  bedrooms             float64
#  17  suites               float64
#  18  parking_spaces       float64
#  19  amenities            object
#  20  geopoint             object
#  21  dt                   object
# dtypes: datetime64[ns](1), float64(7), int32(2), object(12)
# memory usage: 3.0+ GB

# %%
df = df[df["state"] == "espírito santo"]
df = df[df["city"] == "vitória"]
df.head()
# Out:
#      user_id  listing_id         name_raw      event_type browser_family  \
# 143     1955       10211   RankingClicked  LEAD_INTENTION           None
# 144     1955       10211  ListingRendered           VISIT  Chrome Mobile
# 145     1955     1292801   RankingClicked  LEAD_INTENTION  Chrome Mobile
# 146     1955     1292801  ListingRendered           VISIT           None
# 147     1955      500391  ListingRendered           VISIT           None
#
#     os_family collector_timestamp business_type                event_ts  \
# 143      None       1706745772248          SALE 2024-02-01 00:02:52.248
# 144   Android       1706745775165          SALE 2024-02-01 00:02:55.165
# 145   Android       1706746103186          SALE 2024-02-01 00:08:23.186
# 146      None       1706746105978          SALE 2024-02-01 00:08:25.978
# 147      None       1706746009609          SALE 2024-02-01 00:06:49.609
#
#               state  ...      price usable_areas  total_areas  bathrooms  \
# 143  espírito santo  ...  1450000.0        200.0        225.0        5.0
# 144  espírito santo  ...  1450000.0        200.0        225.0        5.0
# 145  espírito santo  ...   550000.0     650000.0          NaN        1.0
# 146  espírito santo  ...   550000.0     650000.0          NaN        1.0
# 147  espírito santo  ...  2700000.0        850.0       1000.0        6.0
#
#      bedrooms  suites  parking_spaces  \
# 143       4.0     2.0             4.0
# 144       4.0     2.0             4.0
# 145       2.0     0.0             4.0
# 146       2.0     0.0             4.0
# 147       5.0     2.0             8.0
#
#                                              amenities  \
# 143  ['BALCONY', 'PAVED_STREET', 'BARBECUE_GRILL', ...
# 144  ['BALCONY', 'PAVED_STREET', 'BARBECUE_GRILL', ...
# 145  ['BARBECUE_GRILL', 'GARDEN', 'ELECTRONIC_GATE'...
# 146  ['BARBECUE_GRILL', 'GARDEN', 'ELECTRONIC_GATE'...
# 147  ['DINNER_ROOM', 'PAVED_STREET', 'COPA', 'KITCH...
#
#                     geopoint          dt
# 143   -40.267894,-20.2599804  2024-02-01
# 144   -40.267894,-20.2599804  2024-02-01
# 145  -40.3339751,-20.2833869  2024-02-01
# 146  -40.3339751,-20.2833869  2024-02-01
# 147  -40.3269799,-20.3071309  2024-02-01
#
# [5 rows x 22 columns]

# %%
df = df.sort_values(by=['user_id', 'event_ts']).reset_index(drop=True)

# %%
df[df["user_id"] == 851].head(50)
# Out:
#       user_id  listing_id         name_raw      event_type  \
# 3075      851      578671   RankingClicked  LEAD_INTENTION
# 3076      851      578671   RankingClicked  LEAD_INTENTION
# 3077      851      578671  ListingRendered           VISIT
# 3078      851      578671  ListingRendered           VISIT
# 3079      851     1367510   RankingClicked  LEAD_INTENTION
# 3080      851     1367510  ListingRendered           VISIT
# 3081      851     1367510      LeadClicked            LEAD
# 3082      851      776478   RankingClicked  LEAD_INTENTION
# 3083      851      776478  ListingRendered           VISIT
# 3084      851     2552791   RankingClicked  LEAD_INTENTION
# 3085      851     2552791  ListingRendered           VISIT
# 3086      851     1159609   RankingClicked  LEAD_INTENTION
# 3087      851     1159609  ListingRendered           VISIT
# 3088      851     2085633   RankingClicked  LEAD_INTENTION
# 3089      851     2085633  ListingRendered           VISIT
#
#                   browser_family os_family collector_timestamp business_type  \
# 3075                        None      None       1708264050586          SALE
# 3076                        None      None       1708264050586        RENTAL
# 3077  Mobile Safari UI/WKWebView       iOS       1708264050588          SALE
# 3078  Mobile Safari UI/WKWebView       iOS       1708264050588        RENTAL
# 3079                        None      None       1709235188207          SALE
# 3080                        None      None       1709235188207          SALE
# 3081                        None      None       1709235337956          SALE
# 3082  Mobile Safari UI/WKWebView       iOS       1720395951815          SALE
# 3083  Mobile Safari UI/WKWebView       iOS       1720395951817          SALE
# 3084                        None      None       1720396191820          SALE
# 3085                        None      None       1720396191822          SALE
# 3086                        None      None       1720396266841          SALE
# 3087  Mobile Safari UI/WKWebView       iOS       1720396266843          SALE
# 3088                        None      None       1720396281820          SALE
# 3089                        None      None       1720396281823          SALE
#
#                     event_ts           state  ...     price usable_areas  \
# 3075 2024-02-18 13:47:30.586  espírito santo  ...  275000.0         49.0
# 3076 2024-02-18 13:47:30.586  espírito santo  ...  275000.0         49.0
# 3077 2024-02-18 13:47:30.588  espírito santo  ...  275000.0         49.0
# 3078 2024-02-18 13:47:30.588  espírito santo  ...  275000.0         49.0
# 3079 2024-02-29 19:33:08.207  espírito santo  ...  480000.0         46.0
# 3080 2024-02-29 19:33:08.207  espírito santo  ...  480000.0         46.0
# 3081 2024-02-29 19:35:37.956  espírito santo  ...  480000.0         46.0
# 3082 2024-07-07 23:45:51.815  espírito santo  ...  170000.0         17.0
# 3083 2024-07-07 23:45:51.817  espírito santo  ...  170000.0         17.0
# 3084 2024-07-07 23:49:51.820  espírito santo  ...  205000.0         12.0
# 3085 2024-07-07 23:49:51.822  espírito santo  ...  205000.0         12.0
# 3086 2024-07-07 23:51:06.841  espírito santo  ...  220000.0         12.0
# 3087 2024-07-07 23:51:06.843  espírito santo  ...  220000.0         12.0
# 3088 2024-07-07 23:51:21.820  espírito santo  ...  260000.0         40.0
# 3089 2024-07-07 23:51:21.823  espírito santo  ...  260000.0         40.0
#
#       total_areas  bathrooms  bedrooms  suites  parking_spaces  \
# 3075         49.0        1.0       1.0     0.0             0.0
# 3076         49.0        1.0       1.0     0.0             0.0
# 3077         49.0        1.0       1.0     0.0             0.0
# 3078         49.0        1.0       1.0     0.0             0.0
# 3079         46.0        1.0       1.0     0.0             1.0
# 3080         46.0        1.0       1.0     0.0             1.0
# 3081         46.0        1.0       1.0     0.0             1.0
# 3082         17.0        1.0       1.0     1.0             1.0
# 3083         17.0        1.0       1.0     1.0             1.0
# 3084         15.0        1.0       1.0     1.0             1.0
# 3085         15.0        1.0       1.0     1.0             1.0
# 3086          NaN        1.0       1.0     1.0             1.0
# 3087          NaN        1.0       1.0     1.0             1.0
# 3088          NaN        1.0       1.0     NaN             1.0
# 3089          NaN        1.0       1.0     NaN             1.0
#
#                                               amenities  \
# 3075                                                 []
# 3076                                                 []
# 3077                                                 []
# 3078                                                 []
# 3079                ['ELEVATOR', 'FURNISHED', 'GARAGE']
# 3080                ['ELEVATOR', 'FURNISHED', 'GARAGE']
# 3081                ['ELEVATOR', 'FURNISHED', 'GARAGE']
# 3082  ['AIR_CONDITIONING', 'KITCHEN_CABINETS', 'GARA...
# 3083  ['AIR_CONDITIONING', 'KITCHEN_CABINETS', 'GARA...
# 3084  ['SECURITY_CAMERA', 'SAFETY_CIRCUIT', 'COFFEE_...
# 3085  ['SECURITY_CAMERA', 'SAFETY_CIRCUIT', 'COFFEE_...
# 3086  ['AIR_CONDITIONING', 'AMERICAN_KITCHEN', 'FURN...
# 3087  ['AIR_CONDITIONING', 'AMERICAN_KITCHEN', 'FURN...
# 3088  ['LAUNDRY', 'GATED_COMMUNITY', 'ELECTRONIC_GAT...
# 3089  ['LAUNDRY', 'GATED_COMMUNITY', 'ELECTRONIC_GAT...
#
#                      geopoint          dt
# 3075  -40.3006106,-20.3028247  2024-02-18
# 3076  -40.3006106,-20.3028247  2024-02-18
# 3077  -40.3006106,-20.3028247  2024-02-18
# 3078  -40.3006106,-20.3028247  2024-02-18
# 3079   -40.267894,-20.2599804  2024-02-29
# 3080   -40.267894,-20.2599804  2024-02-29
# 3081   -40.267894,-20.2599804  2024-02-29
# 3082  -40.3027037,-20.2913934  2024-07-07
# 3083  -40.3027037,-20.2913934  2024-07-07
# 3084  -40.3006106,-20.3028247  2024-07-07
# 3085  -40.3006106,-20.3028247  2024-07-07
# 3086  -40.2994874,-20.3131036  2024-07-07
# 3087  -40.2994874,-20.3131036  2024-07-07
# 3088   -40.267894,-20.2599804  2024-07-07
# 3089   -40.267894,-20.2599804  2024-07-07
#
# [15 rows x 22 columns]

# %%
session_time_in_hours = 24
inactivity_threshold = pd.Timedelta(hours=session_time_in_hours)

time_diff = df.groupby('user_id')['event_ts'].diff()
is_new_session = (time_diff > inactivity_threshold) | (time_diff.isnull())
session_marker = is_new_session.cumsum()
df['session_id'] = df['user_id'].astype(str) + '_' + session_marker.astype(str)

df_session = df[['event_ts', 'user_id', 'listing_id', 'name_raw', 'event_type', 'session_id']]

df_session[df["user_id"] == 851].head(50)
# Out:
#                     event_ts  user_id  listing_id         name_raw  \
# 3075 2024-02-18 13:47:30.586      851      578671   RankingClicked
# 3076 2024-02-18 13:47:30.586      851      578671   RankingClicked
# 3077 2024-02-18 13:47:30.588      851      578671  ListingRendered
# 3078 2024-02-18 13:47:30.588      851      578671  ListingRendered
# 3079 2024-02-29 19:33:08.207      851     1367510   RankingClicked
# 3080 2024-02-29 19:33:08.207      851     1367510  ListingRendered
# 3081 2024-02-29 19:35:37.956      851     1367510      LeadClicked
# 3082 2024-07-07 23:45:51.815      851      776478   RankingClicked
# 3083 2024-07-07 23:45:51.817      851      776478  ListingRendered
# 3084 2024-07-07 23:49:51.820      851     2552791   RankingClicked
# 3085 2024-07-07 23:49:51.822      851     2552791  ListingRendered
# 3086 2024-07-07 23:51:06.841      851     1159609   RankingClicked
# 3087 2024-07-07 23:51:06.843      851     1159609  ListingRendered
# 3088 2024-07-07 23:51:21.820      851     2085633   RankingClicked
# 3089 2024-07-07 23:51:21.823      851     2085633  ListingRendered
#
#           event_type session_id
# 3075  LEAD_INTENTION    851_115
# 3076  LEAD_INTENTION    851_115
# 3077           VISIT    851_115
# 3078           VISIT    851_115
# 3079  LEAD_INTENTION    851_116
# 3080           VISIT    851_116
# 3081            LEAD    851_116
# 3082  LEAD_INTENTION    851_117
# 3083           VISIT    851_117
# 3084  LEAD_INTENTION    851_117
# 3085           VISIT    851_117
# 3086  LEAD_INTENTION    851_117
# 3087           VISIT    851_117
# 3088  LEAD_INTENTION    851_117
# 3089           VISIT    851_117

# %%
df.head(100)
# Out:
#     user_id  listing_id          name_raw      event_type browser_family  \
# 0         5      233878    RankingClicked  LEAD_INTENTION         Chrome
# 1         5      233878   ListingRendered           VISIT         Chrome
# 2         5      643235    RankingClicked  LEAD_INTENTION         Chrome
# 3         5      643235   ListingRendered           VISIT         Chrome
# 4         5      643235  LeadPanelClicked  LEAD_INTENTION         Chrome
# ..      ...         ...               ...             ...            ...
# 95      130      236039  LeadPanelClicked  LEAD_INTENTION           None
# 96      130      236039  LeadPanelClicked  LEAD_INTENTION           Edge
# 97      130      881611  LeadPanelClicked  LEAD_INTENTION           Edge
# 98      130      881611  LeadPanelClicked  LEAD_INTENTION           Edge
# 99      130      237904  LeadPanelClicked  LEAD_INTENTION           None
#
#    os_family collector_timestamp business_type                event_ts  \
# 0    Windows       1713635883412          SALE 2024-04-20 17:58:03.412
# 1    Windows       1713635884767          SALE 2024-04-20 17:58:04.767
# 2    Windows       1713635923016          SALE 2024-04-20 17:58:43.016
# 3    Windows       1713635924189          SALE 2024-04-20 17:58:44.189
# 4    Windows       1713636316478          SALE 2024-04-20 18:05:16.478
# ..       ...                 ...           ...                     ...
# 95      None       1711735778758          SALE 2024-03-29 18:09:38.758
# 96   Windows       1711735779455          SALE 2024-03-29 18:09:39.455
# 97   Windows       1711735779865          SALE 2024-03-29 18:09:39.865
# 98   Windows       1711735780472          SALE 2024-03-29 18:09:40.472
# 99      None       1711735780748          SALE 2024-03-29 18:09:40.748
#
#              state  ... usable_areas total_areas  bathrooms  bedrooms  suites  \
# 0   espírito santo  ...         78.0        78.0        2.0       2.0     0.0
# 1   espírito santo  ...         78.0        78.0        2.0       2.0     0.0
# 2   espírito santo  ...         90.0       120.0        2.0       2.0     2.0
# 3   espírito santo  ...         90.0       120.0        2.0       2.0     2.0
# 4   espírito santo  ...         90.0       120.0        2.0       2.0     2.0
# ..             ...  ...          ...         ...        ...       ...     ...
# 95  espírito santo  ...        100.0         NaN        3.0       3.0     1.0
# 96  espírito santo  ...        100.0         NaN        3.0       3.0     1.0
# 97  espírito santo  ...        264.0       360.0        5.0       4.0     2.0
# 98  espírito santo  ...        264.0       360.0        5.0       4.0     2.0
# 99  espírito santo  ...         65.0         NaN        2.0       2.0     1.0
#
#     parking_spaces                                          amenities  \
# 0              1.0  ['PETS_ALLOWED', 'INTEGRATED_ENVIRONMENTS', 'A...
# 1              1.0  ['PETS_ALLOWED', 'INTEGRATED_ENVIRONMENTS', 'A...
# 2              1.0  ['KITCHEN', 'ELEVATOR', 'INTERCOM', 'LAUNDRY',...
# 3              1.0  ['KITCHEN', 'ELEVATOR', 'INTERCOM', 'LAUNDRY',...
# 4              1.0  ['KITCHEN', 'ELEVATOR', 'INTERCOM', 'LAUNDRY',...
# ..             ...                                                ...
# 95             2.0                                                 []
# 96             2.0                                                 []
# 97             2.0           ['BARBECUE_GRILL', 'GARDEN', 'ELEVATOR']
# 98             2.0           ['BARBECUE_GRILL', 'GARDEN', 'ELEVATOR']
# 99             1.0  ['GYM', 'BARBECUE_GRILL', 'GOURMET_SPACE', 'GA...
#
#                    geopoint          dt session_id
# 0    -40.2946647,-20.298286  2024-04-20        5_1
# 1    -40.2946647,-20.298286  2024-04-20        5_1
# 2    -40.2946647,-20.298286  2024-04-20        5_1
# 3    -40.2946647,-20.298286  2024-04-20        5_1
# 4    -40.2946647,-20.298286  2024-04-20        5_1
# ..                      ...         ...        ...
# 95   -40.267894,-20.2599804  2024-03-29     130_11
# 96   -40.267894,-20.2599804  2024-03-29     130_11
# 97  -40.2966929,-20.2712388  2024-03-29     130_11
# 98  -40.2966929,-20.2712388  2024-03-29     130_11
# 99   -40.267894,-20.2599804  2024-03-29     130_11
#
# [100 rows x 23 columns]

# %%
df_recbole = pd.DataFrame()

# %%
df_recbole['session_id:token'] = df['session_id']
df_recbole['item_id:token'] = df['listing_id']
df_recbole['timestamp:float'] = df['event_ts'].astype('int64') // 10**9

# %%
df_recbole.head(10)
# Out:
#   session_id:token  item_id:token  timestamp:float
# 0              5_1         233878       1713635883
# 1              5_1         233878       1713635884
# 2              5_1         643235       1713635923
# 3              5_1         643235       1713635924
# 4              5_1         643235       1713636316
# 5              5_1         643235       1713636319
# 6              6_2          65574       1709043626
# 7              6_2          65574       1709043635
# 8             13_3        1275761       1713798664
# 9             13_3         943929       1713798722

# %%
import os

dataset_name = 'eventos_vix'
data_path = os.path.join('../gru/dataset', dataset_name)
os.makedirs(data_path, exist_ok=True)
file_path = os.path.join(data_path, f'{dataset_name}.inter')
df_recbole.to_csv(file_path, index=False, sep='\t')
